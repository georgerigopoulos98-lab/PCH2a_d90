# %% [markdown]
# ## Basics jupyter
#
# To visualize local variables, click "Jupyter Variables" in the toolbar which lists all variables in the current kernel with their name, type and value/shape.
# For DataFrames(pandas), arrays(numpy) etc. there's a magnifying glass or "view" icon next to the row, this opens the data viewer.
#
# 1. Display line numbers by typing Ctrl+M followed by L.
#
# 2. print? #Works like help to give info about a command in jupyter.
#
# 3. Shell:
#     * pip install pandas
#     * pip install matplotlib

# %%
#test
okay = 'this'
print(okay)

# %%
#Libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Import and view csv dataframes:
data_oceania = pd.read_csv('python-novice-gapminder-data/data/gapminder_gdp_oceania.csv')
print(data_oceania)
data_oceania.info()
print(data_oceania.columns)

#To save plots use:
plt.savefig('my_plot.png')
#For good visualization, use the fontsize parameter in xlabel, ylabel, title and legend, 
#and tick_params with labelsize to increase the text size of the numbers on the axes.
#Similarly, use s to increase the size of scatterplot markers and linewidth to increase size of the plot lines.
#Linestyle parameter uses different types of lines.
#Marker parameter changes the shape of points in scatterplot.
#Use colorblind options.
